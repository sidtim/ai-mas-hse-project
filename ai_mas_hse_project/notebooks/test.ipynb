# %%
import json

from ai_mas_hse_project.src.create_dataset import parse_problem_from_url

# %%
list_result = []

# %%
# Пример URL (замените на реальный)
problem_url = "https://problems.ru/view_problem_details_new.php?id=87981"

result = parse_problem_from_url(problem_url)

# if result:
#     print("Успешно спарсены данные:")
#     print(json.dumps(result, ensure_ascii=False, indent=2))
# else:
#     print("Не удалось спарсить данные.")
# Out:
# Загружаем с URL: https://problems.ru/view_problem_details_new.php?id=87981

# %%
result
# Out:
# {'id': 87981,
#  'topic': 'Десятичная система счисления',
#  'complexity_level': '2-',
#  'problem': 'Попробуйте найти все натуральные числа, которые больше своей последней цифры в 5 раз',
#  'solution': 'При умножении на 5 последняя цифра не изменилась, значит, она была 0 или 5. Если бы последняя цифра была 0, то всё число было бы 0, а мы ищем натуральные числа. Значит, последняя цифра была 5. А всё число 25. Естественно, больше 25 это число быть не может, поскольку оно в 5 раз больше цифры , т.е. не может превышать 45',
#  'answer': '25'}

# %% [markdown]
# ---

# %%
from ai_mas_hse_project.src.create_dataset import (
    parse_problem_from_url,
    parse_problem,
    save_to_json,
    parse_problem_from_file,
)

# %%
parse_problem_from_file(filename="../data/html_source/65987.html", 
                        main_topic='Алгебра')
# Out:
# {'id': 65987,
#  'topic': 'Алгебра',
#  'subtopic': 'Уравнения в целых числах',
#  'complexity_level': '3+',
#  'problem': 'Число 1047 при делении на A дает остаток 23, а при делении на A + 1 – остаток 7. Найдите A',
#  'solution': 'Так как 1047 даёт остаток 23 при делении на А, то 1047 – 23 = 1024 делится на А. Аналогично 1047 – 7 = 1040 делится на А + 1. Так как 1024 = 210, то А = 2n, где n – натуральное и n ≤ 10. При этом А > 23, поэтому n ≥ 5. Из чисел 25 + 1, 26 + 1, 27 + 1, 28 + 1, 29 + 1, 210 + 1 только 26 + 1 = 65 является делителем числа 1040. Следовательно, А = 26',
#  'answer': '64'}

# %%
# Задачи ниже взяты отсюда https://problems.ru/view_by_subject_new.php?parent=88
list_algarith = [
    87981, 
    87992, 
    88081, 
    88105, 
    88142,
    104122,
    88129,
    88246,
    89919,
    30262,
    30289,
    30832,
    30862,
    30937,
    30941,
    31235,
    32830,
    32838,
    35012,
    88078,
    116023,
    116445,
    116528,
    116534,
    35676,
    34848, # Здесь есть степень. Необходимо посмотреть как выглядит степень в распарсеном виде.
    34938,
    60652,
    64822,
    76501, # Здесь очень много степеней. Посмотреть что они корректно отображаются в распарсенном виде.
    115968, # Здесь очень много степеней. Посмотреть что они корректно отображаются в распарсенном виде.
    61199, # Тригонометрическая задача. Тут можно применить вольфрам-альфа.
    116563,
    103822, # Задача на дроби. Посмотреть корректность отображения
    107706,
    111895,
    61219, # Тригонометрия
    64960, 
    61222, # Тригонометрическое уравнение без ответа и решения. Ответ можно написать самому здесь. Здесь можно применить вольфрам-альфа.
    78008, # Тригонометрическое уравнение, где можно заюзать вольфрам-альфа.
    115444, # Тригонометрическое уравнение. Для проверки ответа можно использовать вольфрам-альфа
    116883, # Тригонометрия. Здесь нет решения, но есть ответ. Ответ можно проверить через вольфрам-альфа. РИСУНОК НА ПОЛ-РЕШЕНИЯ
    111261, # Многочлены
    65636,
    86483,
    35641, # Есть степени
    109027, # Система уравнений
    65425, # С дробями
    60976, # С дробями
    116797, # С дробями
    67400, # С дробями
    61221, # Задача без решения и без ответа, но ее можно решить через вольфрам-альфа
    104102, # Система тригонометрических уравнений
    65985, # Тригонометрия. Тут в решении есть рисунок. Его можно ручками заменить.
    64824, 
    64948,
    116684,
    116875,
    35532,
    64670,
    105103,
    111262, # С дробями
    65987,
    78159,
    66360,
    105085,
    35306, 
    64671, # Тут есть специфические latex символы. Необходимо посмотреть нормально ли они отрисовались
    116439, # ТУТ ЕСТЬ РЕШЕНИЕ 1 И РЕШЕНИЕ 2. НУЖНО РУЧКАМИ ВПИСАТЬ ТОЛЬКО РЕШЕНИЕ 1 !!!!!!!!!!
    76430, 
    65965, 
]

# Задачи ниже взяты отсюда https://problems.ru/view_by_subject_new.php?parent=188
list_combinatorics = [
    60370, # Задача без решения, но с ответом
    30320, # Задача без решения, но с ответом
    30322, # Задача без решения, но с ответом
    30321, # Задача без решения, но с ответом
    30346, # Задача без решения, но с ответом
    30419, 
    30431,
    31083,
    60336,
    60381, # ЗАДАЧА У КОТОРОЙ В ОТВЕТЕ РИСУНОК, НО МОЖНО ВРУЧНУЮ НАПИСАТЬ ОТВЕТ
    30341, 
    30722, # ЗАДАЧА У КОТОРОЙ В ОТВЕТЕ РИСУНОК, НО МОЖНО ВРУЧНУЮ НАПИСАТЬ ОТВЕТ
    60378, # ЗАДАЧА У КОТОРОЙ В ОТВЕТЕ РИСУНОК, НО МОЖНО ВРУЧНУЮ НАПИСАТЬ ОТВЕТ
    60382, # ЗАДАЧА У КОТОРОЙ В ОТВЕТЕ РИСУНОК, НО МОЖНО ВРУЧНУЮ НАПИСАТЬ ОТВЕТ
    60402, # ЗАДАЧА У КОТОРОЙ В ОТВЕТЕ РИСУНОК, НО МОЖНО ВРУЧНУЮ НАПИСАТЬ ОТВЕТ
    30690, # ЗАДАЧА У КОТОРОЙ В РЕШЕНИИ РИСУНОК, НО МОЖНО ВРУЧНУЮ ЗАПИСАТЬ РЕШЕНИЕ
    30697,
    30699, # ЗАДАЧА У КОТОРОЙ В РЕШЕНИИ РИСУНОК, НО МОЖНО ВРУЧНУЮ ЗАПИСАТЬ РЕШЕНИЕ
    30325,
    102999, 
    116799,
    65344,  
    32052,
    35129,
    35479,
    60345, 
    35734,
    60450, # ЗАДАЧА БЕЗ РЕШЕНИЯ, НО С ОТВЕТОМ
    35399, # ЗАДАЧА У КОТОРОЙ В ОТВЕТЕ РИСУНОК, НО МОЖНО ВРУЧНУЮ НАПИСАТЬ ОТВЕТ
    60384,
    60403, # ЗАДАЧА У КОТОРОЙ В ОТВЕТЕ РИСУНОК, НО МОЖНО ВРУЧНУЮ НАПИСАТЬ ОТВЕТ
    111357,
    116990, # ЗАДАЧА У КОТОРОЙ В РЕШЕНИИ РИСУНОК, НО МОЖНО ВРУЧНУЮ ЗАПИСАТЬ РЕШЕНИЕ
    109483, 
    30778,
    35071,
    66576,
    108978,
    109436, # С дробями
    111644,
    115450,
    116885, # ЗАДАЧА У КОТОРОЙ В РЕШЕНИИ РИСУНОК, НО МОЖНО ВРУЧНУЮ ЗАПИСАТЬ РЕШЕНИЕ
    64511, 
    64833,
    66720,
    98470,
]

# Задачи ниже взяты отсюда https://problems.ru/view_by_subject_new.php?parent=208
list_probstat = [
    66038, # ЗАДАЧА БЕЗ РЕШЕНИЯ, НО С ОТВЕТОМ
    65330,
    66034, # ЗАДАЧА БЕЗ РЕШЕНИЯ, НО С ОТВЕТОМ
    65312,
    65265, # С дробями
    65267,
    65333,
    65785,
    35352,
    35178,
    65315,
    65768
]

# Задачи ниже взяты отсюда https://problems.ru/view_by_subject_new.php?parent=265
list_mathan = [
    64891,
    34872,
    98427,
    66354,
    61213, # У данной задачи есть только условие. Решения и ответа нет. Однако его можно получить через вольфрам-альфа.
]

# Задачи ниже взяты отсюда https://problems.ru/view_by_source_new.php?parent=164898
list_olimpiada = [
    67443,
    67455,
    76414,
    105072,
    116226,
    30364,
    76429,
    77964,
    78025,
    78726,
    105197,
    78489,
    105120	
]

print("Количество уникальных задач:", len(list(set(list_algarith + list_combinatorics + list_probstat + list_mathan + list_olimpiada))))
# Out:
# Количество уникальных задач: 147

# %%
list_algarith = list(set(list_algarith))
list_combinatorics = list(set(list_combinatorics))
list_probstat = list(set(list_probstat))
list_mathan = list(set(list_mathan))
list_olimpiada = list(set(list_olimpiada))

# %%
list_all = list_combinatorics + list_probstat + list_mathan + list_olimpiada

# %%
for item in list_all:
    filename = f"../data/html_delete/{item}.html"
    with open(filename, 'w', encoding='utf-8') as f:
        f.write("")  # Пустой файл
    
    print(f"Создан пустой файл: {filename}")
# Out:
# Создан пустой файл: ../data/html_delete/30722.html
# Создан пустой файл: ../data/html_delete/30341.html
# Создан пустой файл: ../data/html_delete/30346.html
# Создан пустой файл: ../data/html_delete/66576.html
# Создан пустой файл: ../data/html_delete/116885.html
# Создан пустой файл: ../data/html_delete/35734.html
# Создан пустой файл: ../data/html_delete/35479.html
# Создан пустой файл: ../data/html_delete/111644.html
# Создан пустой файл: ../data/html_delete/66720.html
# Создан пустой файл: ../data/html_delete/60450.html
# Создан пустой файл: ../data/html_delete/98470.html
# Создан пустой файл: ../data/html_delete/109483.html
# Создан пустой файл: ../data/html_delete/60336.html
# Создан пустой файл: ../data/html_delete/108978.html
# Создан пустой файл: ../data/html_delete/32052.html
# Создан пустой файл: ../data/html_delete/35129.html
# Создан пустой файл: ../data/html_delete/60345.html
# Создан пустой файл: ../data/html_delete/30778.html
# Создан пустой файл: ../data/html_delete/116799.html
# Создан пустой файл: ../data/html_delete/65344.html
# Создан пустой файл: ../data/html_delete/64833.html
# Создан пустой файл: ../data/html_delete/35399.html
# Создан пустой файл: ../data/html_delete/60370.html
# Создан пустой файл: ../data/html_delete/30419.html
# Создан пустой файл: ../data/html_delete/102999.html
# Создан пустой файл: ../data/html_delete/60378.html
# Создан пустой файл: ../data/html_delete/64511.html
# Создан пустой файл: ../data/html_delete/60381.html
# Создан пустой файл: ../data/html_delete/60382.html
# Создан пустой файл: ../data/html_delete/30431.html
# Создан пустой файл: ../data/html_delete/60384.html
# Создан пустой файл: ../data/html_delete/30690.html
# Создан пустой файл: ../data/html_delete/30697.html
# Создан пустой файл: ../data/html_delete/31083.html
# Создан пустой файл: ../data/html_delete/30699.html
# Создан пустой файл: ../data/html_delete/30320.html
# Создан пустой файл: ../data/html_delete/30321.html
# Создан пустой файл: ../data/html_delete/30322.html
# Создан пустой файл: ../data/html_delete/60402.html
# Создан пустой файл: ../data/html_delete/60403.html
# Создан пустой файл: ../data/html_delete/30325.html
# Создан пустой файл: ../data/html_delete/115450.html
# Создан пустой файл: ../data/html_delete/109436.html
# Создан пустой файл: ../data/html_delete/111357.html
# Создан пустой файл: ../data/html_delete/116990.html
# Создан пустой файл: ../data/html_delete/35071.html
# Создан пустой файл: ../data/html_delete/65312.html
# Создан пустой файл: ../data/html_delete/65315.html
# Создан пустой файл: ../data/html_delete/65768.html
# Создан пустой файл: ../data/html_delete/35178.html
# Создан пустой файл: ../data/html_delete/65265.html
# Создан пустой файл: ../data/html_delete/65330.html
# Создан пустой файл: ../data/html_delete/66034.html
# Создан пустой файл: ../data/html_delete/65267.html
# Создан пустой файл: ../data/html_delete/65333.html
# Создан пустой файл: ../data/html_delete/66038.html
# Создан пустой файл: ../data/html_delete/35352.html
# Создан пустой файл: ../data/html_delete/65785.html
# Создан пустой файл: ../data/html_delete/98427.html
# Создан пустой файл: ../data/html_delete/66354.html
# Создан пустой файл: ../data/html_delete/34872.html
# Создан пустой файл: ../data/html_delete/64891.html
# Создан пустой файл: ../data/html_delete/61213.html
# Создан пустой файл: ../data/html_delete/105120.html
# Создан пустой файл: ../data/html_delete/116226.html
# Создан пустой файл: ../data/html_delete/78726.html
# Создан пустой файл: ../data/html_delete/78025.html
# Создан пустой файл: ../data/html_delete/77964.html
# Создан пустой файл: ../data/html_delete/76429.html
# Создан пустой файл: ../data/html_delete/105197.html
# Создан пустой файл: ../data/html_delete/105072.html
# Создан пустой файл: ../data/html_delete/67443.html
# Создан пустой файл: ../data/html_delete/78489.html
# Создан пустой файл: ../data/html_delete/30364.html
# Создан пустой файл: ../data/html_delete/76414.html
# Создан пустой файл: ../data/html_delete/67455.html

# %%
# for item in list_algarith:
#     filename = f"../data/html_source/{item}.html"
#     with open(filename, 'w', encoding='utf-8') as f:
#         f.write("")  # Пустой файл
    
#     print(f"Создан пустой файл: {filename}")
# Out:
# Создан пустой файл: ../data/html_source/115968.html
# Создан пустой файл: ../data/html_source/64824.html
# Создан пустой файл: ../data/html_source/31235.html
# Создан пустой файл: ../data/html_source/116875.html
# Создан пустой файл: ../data/html_source/30862.html
# Создан пустой файл: ../data/html_source/88078.html
# Создан пустой файл: ../data/html_source/61199.html
# Создан пустой файл: ../data/html_source/88081.html
# Создан пустой файл: ../data/html_source/103822.html
# Создан пустой файл: ../data/html_source/116883.html
# Создан пустой файл: ../data/html_source/65425.html
# Создан пустой файл: ../data/html_source/105103.html
# Создан пустой файл: ../data/html_source/76430.html
# Создан пустой файл: ../data/html_source/111895.html
# Создан пустой файл: ../data/html_source/111261.html
# Создан пустой файл: ../data/html_source/78008.html
# Создан пустой файл: ../data/html_source/64670.html
# Создан пустой файл: ../data/html_source/34848.html
# Создан пустой файл: ../data/html_source/111262.html
# Создан пустой файл: ../data/html_source/64671.html
# Создан пустой файл: ../data/html_source/61219.html
# Создан пустой файл: ../data/html_source/61221.html
# Создан пустой файл: ../data/html_source/61222.html
# Создан пустой файл: ../data/html_source/104102.html
# Создан пустой файл: ../data/html_source/88105.html
# Создан пустой файл: ../data/html_source/87981.html
# Создан пустой файл: ../data/html_source/65965.html
# Создан пустой файл: ../data/html_source/116528.html
# Создан пустой файл: ../data/html_source/60976.html
# Создан пустой файл: ../data/html_source/66360.html
# Создан пустой файл: ../data/html_source/64948.html
# Создан пустой файл: ../data/html_source/88246.html
# Создан пустой файл: ../data/html_source/30262.html
# Создан пустой файл: ../data/html_source/87992.html
# Создан пустой файл: ../data/html_source/116023.html
# Создан пустой файл: ../data/html_source/104122.html
# Создан пустой файл: ../data/html_source/116534.html
# Создан пустой файл: ../data/html_source/64822.html
# Создан пустой файл: ../data/html_source/107706.html
# Создан пустой файл: ../data/html_source/32830.html
# Создан пустой файл: ../data/html_source/89919.html
# Создан пустой файл: ../data/html_source/64960.html
# Создан пустой файл: ../data/html_source/88129.html
# Создан пустой файл: ../data/html_source/35641.html
# Создан пустой файл: ../data/html_source/116797.html
# Создан пустой файл: ../data/html_source/35012.html
# Создан пустой файл: ../data/html_source/65985.html
# Создан пустой файл: ../data/html_source/32838.html
# Создан пустой файл: ../data/html_source/65987.html
# Создан пустой файл: ../data/html_source/67400.html
# Создан пустой файл: ../data/html_source/116684.html
# Создан пустой файл: ../data/html_source/35532.html
# Создан пустой файл: ../data/html_source/88142.html
# Создан пустой файл: ../data/html_source/78159.html
# Создан пустой файл: ../data/html_source/30289.html
# Создан пустой файл: ../data/html_source/116563.html
# Создан пустой файл: ../data/html_source/86483.html
# Создан пустой файл: ../data/html_source/76501.html
# Создан пустой файл: ../data/html_source/116439.html
# Создан пустой файл: ../data/html_source/30937.html
# Создан пустой файл: ../data/html_source/35676.html
# Создан пустой файл: ../data/html_source/30941.html
# Создан пустой файл: ../data/html_source/116445.html
# Создан пустой файл: ../data/html_source/109027.html
# Создан пустой файл: ../data/html_source/65636.html
# Создан пустой файл: ../data/html_source/35306.html
# Создан пустой файл: ../data/html_source/60652.html
# Создан пустой файл: ../data/html_source/30832.html
# Создан пустой файл: ../data/html_source/115444.html
# Создан пустой файл: ../data/html_source/34938.html
# Создан пустой файл: ../data/html_source/105085.html

# %%
list_algarith
# Out:
# [115968,
#  64824,
#  31235,
#  116875,
#  30862,
#  88078,
#  61199,
#  88081,
#  103822,
#  116883,
#  65425,
#  105103,
#  76430,
#  111895,
#  111261,
#  78008,
#  64670,
#  34848,
#  111262,
#  64671,
#  61219,
#  61221,
#  61222,
#  104102,
#  88105,
#  87981,
#  65965,
#  116528,
#  60976,
#  66360,
#  64948,
#  88246,
#  30262,
#  87992,
#  116023,
#  104122,
#  116534,
#  64822,
#  107706,
#  32830,
#  89919,
#  64960,
#  88129,
#  35641,
#  116797,
#  35012,
#  65985,
#  32838,
#  65987,
#  67400,
#  116684,
#  35532,
#  88142,
#  78159,
#  30289,
#  116563,
#  86483,
#  76501,
#  116439,
#  30937,
#  35676,
#  30941,
#  116445,
#  109027,
#  65636,
#  35306,
#  60652,
#  30832,
#  115444,
#  34938,
#  105085]

# %%
dict_map = {
    "algarith": "Алгебра и арифметика",
    "combinatorics": "Комбинаторика",
    "probstat": "Вероятность и статистика",
    "mathan": "Математический анализ",
    "logictheory": "Логика и теория множеств",
    "geometry": "Геометрия"
}
