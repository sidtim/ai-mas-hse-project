# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
with open("../data/final_dataset/list_dict_with_tasks.pkl", "rb") as file:
    loaded_list = pickle.load(file)

# %%
df = pd.DataFrame(loaded_list)
df = df.sort_values("id").reset_index(drop=True)

df.head()
# Out:
#       id                 topic                       subtopic  \
# 0  30262  Алгебра и арифметика  Арифметика. Устный счет и т.п
# 1  30289  Алгебра и арифметика          Четность и нечетность
# 2  30320         Комбинаторика           Правило произведения
# 3  30321         Комбинаторика           Правило произведения
# 4  30322         Комбинаторика           Правило произведения
#
#   complexity_level                                            problem  \
# 0                2  Из книги выпал кусок, первая страница которого...
# 1                2  Можно ли доску размером 5×5 заполнить доминошк...
# 2                2  Монету бросают трижды. Сколько разных последов...
# 3                2  Каждую клетку квадратной таблицы 2×2 можно пок...
# 4                2  Сколькими способами можно заполнить одну карто...
#
#                                             solution  \
# 0
# 1  Общее количество клеток (25) не делится на 2, ...
# 2
# 3
# 4
#
#                                   answer
# ...

# %%
df.topic.str.lower().unique(), df.complexity_level_text.str.lower().unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_145491/3590054894.py in ?()
# ----> 1 df.topic.str.lower().unique(), df.complexity_level_text.str.lower().unique()
#
# ~/.cache/pypoetry/virtualenvs/ai-mas-hse-project-VtkJAIkS-py3.12/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'complexity_level_text'

# %%
df['complexity_level_text'] = df['complexity_level'].map({'2-': 'Легкий',
                                                          '2': 'Легкий',
                                                          '2+': 'Средний',
                                                          '3-': 'Средний',
                                                          '3': 'Сложный',
                                                          '3+': 'Сложный'})

# %%
(
    df.complexity_level.value_counts().sort_index(),
    df.complexity_level_text.value_counts().sort_index()
)
# Out:
# (complexity_level
#  2     30
#  2+    27
#  2-     9
#  3     35
#  3+    33
#  3-    13
#  Name: count, dtype: int64,
#  complexity_level_text
#  Легкий     39
#  Сложный    68
#  Средний    40
#  Name: count, dtype: int64)

# %%
reverted_list = df.to_dict('records')

# %%
with open("../data/final_dataset/list_dict_with_tasks_update.pkl", "wb") as file:
    pickle.dump(reverted_list, file)

# %%
with open("../static_dataset/list_dict_with_tasks_update.pkl", "wb") as file:
    pickle.dump(reverted_list, file)

# %% [markdown]
# # Задачи для MCP

# %%
# ============ MCP УРАВНЕНИЯ ============
MCP_EQUATIONS = [
    {
        "id": 1,
        "problem": "Реши уравнение: x**2 - 5*x + 6 = 0. Какие корни?",
        "ground_truth": "2, 3",
        "hint": "Квадратное уравнение"
    },
    {
        "id": 2,
        "problem": "Найди производную функции f(x) = x**3 + 2*x**2 - 5*x + 1",
        "ground_truth": "3*x**2 + 4*x - 5",
        "hint": "Дифференцирование"
    },
    {
        "id": 3,
        "problem": "Вычисли неопределенный интеграл от 2*x + 3",
        "ground_truth": "x**2 + 3*x",
        "hint": "Интегрирование"
    },
    {
        "id": 4,
        "problem": "Найди среднее значение чисел: 10, 20, 30, 40, 50",
        "ground_truth": "30",
        "hint": "Статистика"
    },
    {
        "id": 5,
        "problem": "Реши систему: сначала найди x из x**2 - 9 = 0, потом проверь, что x > 0",
        "ground_truth": "3",
        "hint": "Система уравнений"
    }
]

# %%
# ============ MCP УРАВНЕНИЯ ============
MCP_EQUATIONS = [
    # === Квадратное уравнение (22 задачи) ===
    {"id": 1, "problem": "Реши уравнение: x**2 - 7*x + 12 = 0. Найди корни.", "ground_truth": "3, 4", "hint": "Квадратное уравнение"},
    {"id": 2, "problem": "Реши уравнение: 2*x**2 - 8*x + 6 = 0. Укажи корни через запятую.", "ground_truth": "1, 3", "hint": "Квадратное уравнение"},
    {"id": 3, "problem": "Найди корни квадратного уравнения: x**2 + 4*x - 5 = 0.", "ground_truth": "-5, 1", "hint": "Квадратное уравнение"},
    {"id": 4, "problem": "Реши уравнение: x**2 - 6*x + 9 = 0. Сколько корней?", "ground_truth": "3", "hint": "Квадратное уравнение"},
    {"id": 5, "problem": "Реши уравнение: 3*x**2 + 5*x - 2 = 0. Запиши корни в порядке возрастания.", "ground_truth": "-2, 0.3333333333333333", "hint": "Квадратное уравнение"},
    {"id": 6, "problem": "Найди дискриминант и корни: x**2 - 2*x - 8 = 0.", "ground_truth": "-2, 4", "hint": "Квадратное уравнение"},
    {"id": 7, "problem": "Реши уравнение: 4*x**2 - 12*x + 9 = 0.", "ground_truth": "1.5", "hint": "Квадратное уравнение"},
    {"id": 8, "problem": "Найди корни: x**2 + 6*x + 8 = 0.", "ground_truth": "-4, -2", "hint": "Квадратное уравнение"},
    {"id": 9, "problem": "Реши уравнение: 5*x**2 - 3*x - 2 = 0.", "ground_truth": "-0.4, 1", "hint": "Квадратное уравнение"},
    {"id": 10, "problem": "Реши уравнение: x**2 - 3*x - 10 = 0.", "ground_truth": "-2, 5", "hint": "Квадратное уравнение"},
    {"id": 11, "problem": "Найди корни: 2*x**2 + 5*x - 3 = 0.", "ground_truth": "-3, 0.5", "hint": "Квадратное уравнение"},
    {"id": 12, "problem": "Реши уравнение: x**2 - 9*x + 20 = 0.", "ground_truth": "4, 5", "hint": "Квадратное уравнение"},
    {"id": 13, "problem": "Реши уравнение: 6*x**2 - 11*x + 3 = 0.", "ground_truth": "0.3333333333333333, 1.5", "hint": "Квадратное уравнение"},
    {"id": 14, "problem": "Найди корни: x**2 + 5*x - 14 = 0.", "ground_truth": "-7, 2", "hint": "Квадратное уравнение"},
    {"id": 15, "problem": "Реши уравнение: 4*x**2 - 7*x - 2 = 0.", "ground_truth": "-0.25, 2", "hint": "Квадратное уравнение"},
    {"id": 16, "problem": "Реши уравнение: x**2 - 8*x + 15 = 0.", "ground_truth": "3, 5", "hint": "Квадратное уравнение"},
    {"id": 17, "problem": "Найди корни: 3*x**2 + 8*x + 4 = 0.", "ground_truth": "-2, -0.6666666666666666", "hint": "Квадратное уравнение"},
    {"id": 18, "problem": "Реши уравнение: x**2 - 4*x - 12 = 0.", "ground_truth": "-2, 6", "hint": "Квадратное уравнение"},
    {"id": 19, "problem": "Реши уравнение: 5*x**2 + 2*x - 3 = 0.", "ground_truth": "-1, 0.6", "hint": "Квадратное уравнение"},
    {"id": 20, "problem": "Найди корни: x**2 - 11*x + 30 = 0.", "ground_truth": "5, 6", "hint": "Квадратное уравнение"},
    {"id": 21, "problem": "Реши уравнение: 2*x**2 - 3*x - 5 = 0.", "ground_truth": "-1, 2.5", "hint": "Квадратное уравнение"},
    {"id": 22, "problem": "Реши уравнение: x**2 + 2*x - 15 = 0.", "ground_truth": "-5, 3", "hint": "Квадратное уравнение"},

    # === Дифференцирование (22 задачи) ===
    {"id": 23, "problem": "Найди производную функции f(x) = 4*x**3 - 2*x**2 + x - 7.", "ground_truth": "12*x**2 - 4*x + 1", "hint": "Дифференцирование"},
    {"id": 24, "problem": "Вычисли производную: f(x) = 5*x**4 - 3*x**2 + 8.", "ground_truth": "20*x**3 - 6*x", "hint": "Дифференцирование"},
    {"id": 25, "problem": "Найди f'(x) для f(x) = x**5 - 2*x**3 + 4*x.", "ground_truth": "5*x**4 - 6*x**2 + 4", "hint": "Дифференцирование"},
    {"id": 26, "problem": "Производная функции f(x) = 3*x**2 + 7*x - 2.", "ground_truth": "6*x + 7", "hint": "Дифференцирование"},
    {"id": 27, "problem": "Найди производную: f(x) = 2*x**3 - x**2 + 5*x - 10.", "ground_truth": "6*x**2 - 2*x + 5", "hint": "Дифференцирование"},
    {"id": 28, "problem": "Вычисли f'(x) для f(x) = x**4 + 3*x**3 - 2*x.", "ground_truth": "4*x**3 + 9*x**2 - 2", "hint": "Дифференцирование"},
    {"id": 29, "problem": "Найди производную: f(x) = 7*x**2 - 4*x + 1.", "ground_truth": "14*x - 4", "hint": "Дифференцирование"},
    {"id": 30, "problem": "Производная функции f(x) = 2*x**5 - x**2 + 6.", "ground_truth": "10*x**4 - 2*x", "hint": "Дифференцирование"},
    {"id": 31, "problem": "Найди f'(x) для f(x) = 3*x**3 + 2*x**2 - x + 9.", "ground_truth": "9*x**2 + 4*x - 1", "hint": "Дифференцирование"},
    {"id": 32, "problem": "Вычисли производную: f(x) = x**6 - 4*x**4 + 3*x.", "ground_truth": "6*x**5 - 16*x**3 + 3", "hint": "Дифференцирование"},
    {"id": 33, "problem": "Найди производную: f(x) = 2*x**2 + 3*sin(x).", "ground_truth": "4*x + 3*cos(x)", "hint": "Дифференцирование"},
    {"id": 34, "problem": "Производная функции f(x) = e**x + x**3.", "ground_truth": "e**x + 3*x**2", "hint": "Дифференцирование"},
    {"id": 35, "problem": "Найди f'(x) для f(x) = ln(x) + x**2.", "ground_truth": "1/x + 2*x", "hint": "Дифференцирование"},
    {"id": 36, "problem": "Вычисли производную: f(x) = 5*cos(x) - 2*x**3.", "ground_truth": "-5*sin(x) - 6*x**2", "hint": "Дифференцирование"},
    {"id": 37, "problem": "Найди производную: f(x) = x**2 * e**x.", "ground_truth": "2*x*e**x + x**2*e**x", "hint": "Дифференцирование"},
    {"id": 38, "problem": "Производная функции f(x) = (x**2 + 1)**3.", "ground_truth": "6*x*(x**2 + 1)**2", "hint": "Дифференцирование"},
    {"id": 39, "problem": "Найди f'(x) для f(x) = sqrt(x) + 1/x.", "ground_truth": "1/(2*sqrt(x)) - 1/x**2", "hint": "Дифференцирование"},
    {"id": 40, "problem": "Вычисли производную: f(x) = 3*tg(x) - 2*x.", "ground_truth": "3/(cos(x)**2) - 2", "hint": "Дифференцирование"},
    {"id": 41, "problem": "Найди производную: f(x) = x**3 * ln(x).", "ground_truth": "3*x**2*ln(x) + x**2", "hint": "Дифференцирование"},
    {"id": 42, "problem": "Производная функции f(x) = 2**x + x**4.", "ground_truth": "2**x*ln(2) + 4*x**3", "hint": "Дифференцирование"},
    {"id": 43, "problem": "Найди f'(x) для f(x) = sin(x) * cos(x).", "ground_truth": "cos(x)**2 - sin(x)**2", "hint": "Дифференцирование"},
    {"id": 44, "problem": "Вычисли производную: f(x) = (x**2 - 3)/(x + 1).", "ground_truth": "(2*x*(x+1) - (x**2 - 3))/(x+1)**2", "hint": "Дифференцирование"},

    # === Интегрирование (22 задачи) ===
    {"id": 45, "problem": "Вычисли неопределенный интеграл: ∫ (3*x**2 - 4*x + 2) dx.", "ground_truth": "x**3 - 2*x**2 + 2*x", "hint": "Интегрирование"},
    {"id": 46, "problem": "Найди интеграл: ∫ (5*x**4 - 3*x**2) dx.", "ground_truth": "x**5 - x**3", "hint": "Интегрирование"},
    {"id": 47, "problem": "Вычисли ∫ (6*x**2 + 2*x - 1) dx.", "ground_truth": "2*x**3 + x**2 - x", "hint": "Интегрирование"},
    {"id": 48, "problem": "Найди интеграл: ∫ (x**3 + 4*x) dx.", "ground_truth": "x**4/4 + 2*x**2", "hint": "Интегрирование"},
    {"id": 49, "problem": "Вычисли ∫ (2*x + 7) dx.", "ground_truth": "x**2 + 7*x", "hint": "Интегрирование"},
    {"id": 50, "problem": "Найди интеграл: ∫ (4*x**3 - 2*x + 1) dx.", "ground_truth": "x**4 - x**2 + x", "hint": "Интегрирование"},
    {"id": 51, "problem": "Вычисли ∫ (3*x**2 + 8) dx.", "ground_truth": "x**3 + 8*x", "hint": "Интегрирование"},
    {"id": 52, "problem": "Найди интеграл: ∫ (x**4 - 6*x**2) dx.", "ground_truth": "x**5/5 - 2*x**3", "hint": "Интегрирование"},
    {"id": 53, "problem": "Вычисли ∫ (1/x**2) dx.", "ground_truth": "-1/x", "hint": "Интегрирование"},
    {"id": 54, "problem": "Найди интеграл: ∫ (5*cos(x)) dx.", "ground_truth": "5*sin(x)", "hint": "Интегрирование"},
    {"id": 55, "problem": "Вычисли ∫ (3*e**x) dx.", "ground_truth": "3*e**x", "hint": "Интегрирование"},
    {"id": 56, "problem": "Найди интеграл: ∫ (sin(x) + cos(x)) dx.", "ground_truth": "-cos(x) + sin(x)", "hint": "Интегрирование"},
    {"id": 57, "problem": "Вычисли ∫ (4*x**3 + 2*sin(x)) dx.", "ground_truth": "x**4 - 2*cos(x)", "hint": "Интегрирование"},
    {"id": 58, "problem": "Найди интеграл: ∫ (2/x + x) dx.", "ground_truth": "2*ln(|x|) + x**2/2", "hint": "Интегрирование"},
    {"id": 59, "problem": "Вычисли ∫ (6*x**5 - 4*x**2) dx.", "ground_truth": "x**6 - (4/3)*x**3", "hint": "Интегрирование"},
    {"id": 60, "problem": "Найди интеграл: ∫ (1/(1 + x**2)) dx.", "ground_truth": "arctan(x)", "hint": "Интегрирование"},
    {"id": 61, "problem": "Вычисли ∫ (sec(x)*tan(x)) dx.", "ground_truth": "sec(x)", "hint": "Интегрирование"},
    {"id": 62, "problem": "Найди интеграл: ∫ (x*e**x) dx.", "ground_truth": "x*e**x - e**x", "hint": "Интегрирование"},
    {"id": 63, "problem": "Вычисли ∫ (ln(x)) dx.", "ground_truth": "x*ln(x) - x", "hint": "Интегрирование"},
    {"id": 64, "problem": "Найди интеграл: ∫ (x**2 * sin(x)) dx (по частям).", "ground_truth": "-x**2*cos(x) + 2*x*sin(x) + 2*cos(x)", "hint": "Интегрирование"},
    {"id": 65, "problem": "Вычисли ∫ (2**x) dx.", "ground_truth": "2**x / ln(2)", "hint": "Интегрирование"},
    {"id": 66, "problem": "Найди интеграл: ∫ (1/sqrt(1 - x**2)) dx.", "ground_truth": "arcsin(x)", "hint": "Интегрирование"},

    # === Статистика (22 задачи) ===
    {"id": 67, "problem": "Найди среднее арифметическое чисел: 5, 10, 15, 20, 25.", "ground_truth": "15", "hint": "Статистика"},
    {"id": 68, "problem": "Вычисли медиану ряда: 3, 7, 9, 12, 15, 21, 23.", "ground_truth": "12", "hint": "Статистика"},
    {"id": 69, "problem": "Найди моду набора: 2, 3, 5, 3, 7, 3, 8, 9.", "ground_truth": "3", "hint": "Статистика"},
    {"id": 70, "problem": "Вычисли дисперсию чисел: 4, 8, 6, 5, 3 (считай генеральную дисперсию).", "ground_truth": "2.8", "hint": "Статистика"},
    {"id": 71, "problem": "Найди среднее значение выборки: 12, 14, 16, 18, 20.", "ground_truth": "16", "hint": "Статистика"},
    {"id": 72, "problem": "Вычисли стандартное отклонение для чисел: 2, 4, 6, 8, 10 (генеральное).", "ground_truth": "2.8284271247461903", "hint": "Статистика"},
    {"id": 73, "problem": "Найди размах ряда: 5, 12, 8, 23, 15, 7.", "ground_truth": "18", "hint": "Статистика"},
    {"id": 74, "problem": "Дана выборка: 1, 3, 5, 7, 9. Найди среднее квадратическое отклонение (не смещённое).", "ground_truth": "3.1622776601683795", "hint": "Статистика"},
    {"id": 75, "problem": "Вычисли третий квартиль для данных: 10, 20, 30, 40, 50, 60, 70.", "ground_truth": "60", "hint": "Статистика"},
    {"id": 76, "problem": "Найди первый квартиль: 1, 2, 3, 4, 5, 6, 7, 8, 9.", "ground_truth": "2.5", "hint": "Статистика"},
    {"id": 77, "problem": "Определи межквартильный размах: 5, 7, 8, 9, 10, 12, 15, 18, 20, 22.", "ground_truth": "11", "hint": "Статистика"},
    {"id": 78, "problem": "Средний рост пяти учеников: 160, 165, 170, 175, 180 см. Найди средний рост.", "ground_truth": "170", "hint": "Статистика"},
    {"id": 79, "problem": "В классе оценки: 4, 5, 3, 4, 5, 5, 2, 4. Найди моду.", "ground_truth": "4,5", "hint": "Статистика"},
    {"id": 80, "problem": "Даны числа: 2, 4, 6, 8, 10. Найди сумму квадратов отклонений от среднего.", "ground_truth": "40", "hint": "Статистика"},
    {"id": 81, "problem": "Вычисли выборочную дисперсию: 1, 2, 3, 4, 5.", "ground_truth": "2.5", "hint": "Статистика"},
    {"id": 82, "problem": "Найди коэффициент вариации (в %) для выборки: 10, 20, 30, 40, 50. Среднее=30, ст. откл.≈15.81.", "ground_truth": "52.7", "hint": "Статистика"},
    {"id": 83, "problem": "Вероятность успеха = 0.7. Найди математическое ожидание биномиального распределения с n=10.", "ground_truth": "7", "hint": "Статистика"},
    {"id": 84, "problem": "Стандартное отклонение выборки: 5, 7, 9, 11, 13 (выборочное).", "ground_truth": "3.1622776601683795", "hint": "Статистика"},
    {"id": 85, "problem": "Найди z-оценку для значения 85, если среднее=75, ст. откл.=5.", "ground_truth": "2", "hint": "Статистика"},
    {"id": 86, "problem": "Дана выборка: 0, 2, 4, 6, 8. Найди медиану.", "ground_truth": "4", "hint": "Статистика"},
    {"id": 87, "problem": "Вычисли среднее геометрическое чисел: 4, 16.", "ground_truth": "8", "hint": "Статистика"},
    {"id": 88, "problem": "Найди среднее гармоническое чисел: 2, 4, 8.", "ground_truth": "3.4285714285714284", "hint": "Статистика"},

    # === Система уравнений (22 задачи) ===
    {"id": 89, "problem": "Реши систему: x + y = 10, x - y = 2. Найди x и y.", "ground_truth": "x=6, y=4", "hint": "Система уравнений"},
    {"id": 90, "problem": "Найди решение: 2*x + y = 7, x - y = 2.", "ground_truth": "x=3, y=1", "hint": "Система уравнений"},
    {"id": 91, "problem": "Реши систему: x**2 + y**2 = 25, x + y = 7. Найди пары (x,y).", "ground_truth": "(3,4), (4,3)", "hint": "Система уравнений"},
    {"id": 92, "problem": "Найди x и y: 3*x - 2*y = 5, x + 3*y = 9.", "ground_truth": "x=3, y=2", "hint": "Система уравнений"},
    {"id": 93, "problem": "Реши систему: y = 2*x + 1, y = x**2 - 3.", "ground_truth": "x=-2, y=-3; x=2, y=5", "hint": "Система уравнений"},
    {"id": 94, "problem": "Найди решение: x + 2*y = 5, 3*x - y = 1.", "ground_truth": "x=1, y=2", "hint": "Система уравнений"},
    {"id": 95, "problem": "Реши систему: x**2 - y**2 = 0, x + y = 2.", "ground_truth": "x=1, y=1", "hint": "Система уравнений"},
    {"id": 96, "problem": "Найди x,y: 4*x + 3*y = 18, 2*x - y = 4.", "ground_truth": "x=3, y=2", "hint": "Система уравнений"},
    {"id": 97, "problem": "Реши систему: x*y = 6, x + y = 5.", "ground_truth": "(2,3), (3,2)", "hint": "Система уравнений"},
    {"id": 98, "problem": "Найди решение: 2*x + 5*y = 16, 3*x - 2*y = 5.", "ground_truth": "x=3, y=2", "hint": "Система уравнений"},
    {"id": 99, "problem": "Реши систему: x**2 + y = 7, x - y = 1.", "ground_truth": "x=2, y=1; x=-3, y=-4", "hint": "Система уравнений"},
    {"id": 100, "problem": "Найди x,y: 5*x - 3*y = 1, 2*x + 4*y = 16.", "ground_truth": "x=2, y=3", "hint": "Система уравнений"},
    {"id": 101, "problem": "Реши систему: y = x**2 - 4, y = 3*x.", "ground_truth": "x=-1, y=-3; x=4, y=12", "hint": "Система уравнений"},
    {"id": 102, "problem": "Найди решение: x/2 + y/3 = 1, x/3 + y/2 = 1.", "ground_truth": "x=1.2, y=1.2", "hint": "Система уравнений"},
    {"id": 103, "problem": "Реши систему: x + y = 8, x*y = 15.", "ground_truth": "(3,5), (5,3)", "hint": "Система уравнений"},
    {"id": 104, "problem": "Найди x,y: 2*x - y = 0, x**2 + y**2 = 20.", "ground_truth": "x=2, y=4; x=-2, y=-4", "hint": "Система уравнений"},
    {"id": 105, "problem": "Реши систему: x + y = 12, x - y = 4.", "ground_truth": "x=8, y=4", "hint": "Система уравнений"},
    {"id": 106, "problem": "Найди решение: 3*x + 2*y = 14, 5*x - 3*y = 17.", "ground_truth": "x=4, y=1", "hint": "Система уравнений"},
    {"id": 107, "problem": "Реши систему: x**2 + x*y = 12, y = x + 2.", "ground_truth": "x=2, y=4; x=-6, y=-4", "hint": "Система уравнений"},
    {"id": 108, "problem": "Найди x,y: 2*x + 3*y = 13, 4*x - y = 5.", "ground_truth": "x=2, y=3", "hint": "Система уравнений"},
    {"id": 109, "problem": "Реши систему: x + y = 9, x**2 - y**2 = 27.", "ground_truth": "x=6, y=3", "hint": "Система уравнений"},
    {"id": 110, "problem": "Найди решение: x*y = 8, x + y = 6.", "ground_truth": "(2,4), (4,2)", "hint": "Система уравнений"},
]

# %%
with open("../static_dataset/mcp_equations.pkl", "wb") as file:
    pickle.dump(MCP_EQUATIONS, file)
